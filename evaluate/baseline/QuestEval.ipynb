# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.11.0-0/Mambaforge-23.11.0-0-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:15
# 🔁 Restarting kernel...

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/ThomasScialom/QuestEval.git
# Out:
# Cloning into 'QuestEval'...
# remote: Enumerating objects: 634, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 634 (delta 2), reused 0 (delta 0), pack-reused 616 (from 1)
# Receiving objects: 100% (634/634), 897.51 KiB | 13.60 MiB/s, done.
# Resolving deltas: 100% (274/274), done.

# %%
# !conda create --name myenv python=3.9
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/myenv
#
#   added / updated specs:
#     - python=3.9
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bzip2-1.0.8                |       h4bc722e_7         247 KB  conda-forge
#     ca-certificates-2024.8.30  |       hbcca054_0         155 KB  conda-forge
#     ld_impl_linux-64-2.43      |       h712a8e2_2         654 KB  conda-forge
#     libgcc-14.2.0              |       h77fa898_1         829 KB  conda-forge
#     libgcc-ng-14.2.0           |       h69a702a_1          53 KB  conda-forge
#     libgomp-14.2.0             |       h77fa898_1         450 KB  conda-forge
#     liblzma-5.6.3              |       hb9d3cd8_1         109 KB  conda-forge
#     libsqlite-3.47.2           |       hee588c1_0         853 KB  conda-forge
#     libxcrypt-4.4.36           |       hd590300_1          98 KB  conda-forge
#     libzlib-1.3.1              |       hb9d3cd8_2          60 KB  conda-forge
#     ncurses-6.5                |       he02047a_1         868 KB  conda-forge
#     openssl-3.4.0              |       hb9d3cd8_0         2.8 MB  conda-forge
#     pip-24.3.1                 |     pyh8b19718_0         1.2 MB  conda-forge
#     python-3.9.21              |h9c0c6dc_1_cpython        22.5 MB  conda-forge
#     setuptools-75.6.0          |     pyhff2d567_1         756 KB  conda-forge
#     tzdata-2024b               |       hc8b5060_0         119 KB  conda-forge
#     wheel-0.45.1               |     pyhd8ed1ab_1          61 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        31.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      conda-forge/linux-64::_libgcc_mutex-0.1-conda_forge
#   _openmp_mutex      conda-forge/linux-64::_openmp_mutex-4.5-2_gnu
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-h4bc722e_7
#   ca-certificates    conda-forge/linux-64::ca-certificates-2024.8.30-hbcca054_0
#   ld_impl_linux-64   conda-forge/linux-64::ld_impl_linux-64-2.43-h712a8e2_2
#   libffi             conda-forge/linux-64::libffi-3.4.2-h7f98852_5
#   libgcc             conda-forge/linux-64::libgcc-14.2.0-h77fa898_1
#   libgcc-ng          conda-forge/linux-64::libgcc-ng-14.2.0-h69a702a_1
#   libgomp            conda-forge/linux-64::libgomp-14.2.0-h77fa898_1
#   liblzma            conda-forge/linux-64::liblzma-5.6.3-hb9d3cd8_1
#   libnsl             conda-forge/linux-64::libnsl-2.0.1-hd590300_0
#   libsqlite          conda-forge/linux-64::libsqlite-3.47.2-hee588c1_0
#   libuuid            conda-forge/linux-64::libuuid-2.38.1-h0b41bf4_0
#   libxcrypt          conda-forge/linux-64::libxcrypt-4.4.36-hd590300_1
#   libzlib            conda-forge/linux-64::libzlib-1.3.1-hb9d3cd8_2
#   ncurses            conda-forge/linux-64::ncurses-6.5-he02047a_1
#   openssl            conda-forge/linux-64::openssl-3.4.0-hb9d3cd8_0
#   pip                conda-forge/noarch::pip-24.3.1-pyh8b19718_0
#   python             conda-forge/linux-64::python-3.9.21-h9c0c6dc_1_cpython
#   readline           conda-forge/linux-64::readline-8.2-h8228510_1
#   setuptools         conda-forge/noarch::setuptools-75.6.0-pyhff2d567_1
#   tk                 conda-forge/linux-64::tk-8.6.13-noxft_h4845f30_101
#   tzdata             conda-forge/noarch::tzdata-2024b-hc8b5060_0
#   wheel              conda-forge/noarch::wheel-0.45.1-pyhd8ed1ab_1
#
#
#
# Downloading and Extracting Packages:
# python-3.9.21        | 22.5 MB   | :   0% 0/1 [00:00<?, ?it/s]
# openssl-3.4.0        | 2.8 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
# pip-24.3.1           | 1.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# ncurses-6.5          | 868 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# libsqlite-3.47.2     | 853 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# libgcc-14.2.0        | 829 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# setuptools-75.6.0    | 756 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 654 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# libgomp-14.2.0       | 450 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# bzip2-1.0.8          | 247 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# ca-certificates-2024 | 155 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# tzdata-2024b         | 119 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# liblzma-5.6.3        | 109 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# libxcrypt-4.4.36     | 98 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# wheel-0.45.1         | 61 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libzlib-1.3.1        | 60 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.9.21        | 22.5 MB   | :   0% 0.0006935658223767092/1 [00:00<03:15, 195.95s/it]
# openssl-3.4.0        | 2.8 MB    | :   1% 0.005558673111072358/1 [00:00<00:25, 25.96s/it]
#
#
#
# libsqlite-3.47.2     | 853 KB    | :   2% 0.01875563075309856/1 [00:00<00:07,  7.80s/it]
#
# pip-24.3.1           | 1.2 MB    | :   1% 0.013179232412674715/1 [00:00<00:11, 11.87s/it]
#
#
# python-3.9.21        | 22.5 MB   | :   3% 0.02635550125031495/1 [00:00<00:07,  7.49s/it]
# openssl-3.4.0        | 2.8 MB    | :  28% 0.27793365555361793/1 [00:00<00:00,  1.37it/s]
#
# pip-24.3.1           | 1.2 MB    | :  58% 0.5798862261576875/1 [00:00<00:00,  2.70it/s]
#
#
# ncurses-6.5          | 868 KB    | :  63% 0.6265490627453362/1 [00:00<00:00,  2.90it/s]
#
#
#
#
# python-3.9.21        | 22.5 MB   | :  14% 0.14010029612009525/1 [00:00<00:01,  1.81s/it]
#
#
#
#
#
# setuptools-75.6.0    | 756 KB    | :   2% 0.021161069005956715/1 [00:00<00:15, 16.11s/it]
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 654 KB    | :   2% 0.024482562300978315/1 [00:00<00:13, 14.22s/it]
#
#
#
# libsqlite-3.47.2     | 853 KB    | : 100% 1.0/1 [00:00<00:00,  2.78it/s]
#
#
#
# libsqlite-3.47.2     | 853 KB    | : 100% 1.0/1 [00:00<00:00,  2.78it/s]
#
#
#
#
#
#
#
# python-3.9.21        | 22.5 MB   | :  20% 0.2032147859563758/1 [00:00<00:01,  1.72s/it]
#
#
#
#
#
#
#
#
#
#
# tzdata-2024b         | 119 KB    | :  13% 0.1339065335011524/1 [00:00<00:02,  3.26s/it]
#
#
#
#
#
#
#
#
#
# ca-certificates-2024 | 155 KB    | :  10% 0.10304208096702577/1 [00:00<00:03,  4.30s/it]
#
#
#
#
#
#
#
#
# bzip2-1.0.8          | 247 KB    | :   6% 0.06481448515129577/1 [00:00<00:06,  6.86s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# libxcrypt-4.4.36     | 98 KB     | :  16% 0.163198629386511/1 [00:00<00:02,  3.08s/it]
#
#
#
#
#
#
#
#
#
#
#
# liblzma-5.6.3        | 109 KB    | :  15% 0.14742828348270526/1 [00:00<00:02,  3.47s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.9.21        | 22.5 MB   | :  34% 0.34054081878696424/1 [00:00<00:00,  1.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libzlib-1.3.1        | 60 KB     | :  27% 0.2687531781572429/1 [00:00<00:01,  2.00s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.9.21        | 22.5 MB   | :  82% 0.8177141045821401/1 [00:00<00:00,  1.69it/s]
#
# pip-24.3.1           | 1.2 MB    | : 100% 1.0/1 [00:01<00:00,  1.13s/it]
#
# pip-24.3.1           | 1.2 MB    | : 100% 1.0/1 [00:01<00:00,  1.13s/it]
#
#
#
#
# libgcc-14.2.0        | 829 KB    | : 100% 1.0/1 [00:01<00:00,  1.08s/it]
#
#
#
#
# libgcc-14.2.0        | 829 KB    | : 100% 1.0/1 [00:01<00:00,  1.08s/it]
#
#
#
#
#
# setuptools-75.6.0    | 756 KB    | : 100% 1.0/1 [00:01<00:00,  1.58s/it]
#
#
#
#
#
# setuptools-75.6.0    | 756 KB    | : 100% 1.0/1 [00:01<00:00,  1.58s/it]
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 654 KB    | : 100% 1.0/1 [00:01<00:00,  1.65s/it]
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 654 KB    | : 100% 1.0/1 [00:01<00:00,  1.65s/it]
# openssl-3.4.0        | 2.8 MB    | : 100% 1.0/1 [00:02<00:00,  2.14s/it]
# openssl-3.4.0        | 2.8 MB    | : 100% 1.0/1 [00:02<00:00,  2.14s/it]
#
#
#
#
#
#
#
# libgomp-14.2.0       | 450 KB    | : 100% 1.0/1 [00:02<00:00,  2.04s/it]
#
#
#
#
#
#
#
# libgomp-14.2.0       | 450 KB    | : 100% 1.0/1 [00:02<00:00,  2.04s/it]
#
#
# ncurses-6.5          | 868 KB    | : 100% 1.0/1 [00:02<00:00,  3.02s/it]
#
#
# ncurses-6.5          | 868 KB    | : 100% 1.0/1 [00:02<00:00,  3.02s/it]
#
#
#
#
#
#
#
#
#
# ca-certificates-2024 | 155 KB    | : 100% 1.0/1 [00:02<00:00,  2.51s/it]
#
#
#
#
#
#
#
#
#
# ca-certificates-2024 | 155 KB    | : 100% 1.0/1 [00:02<00:00,  2.51s/it]
#
#
#
#
#
#
#
#
#
#
# tzdata-2024b         | 119 KB    | : 100% 1.0/1 [00:02<00:00,  2.59s/it]
#
#
#
#
#
#
#
#
#
#
# tzdata-2024b         | 119 KB    | : 100% 1.0/1 [00:02<00:00,  2.59s/it]
#
#
#
#
#
#
#
#
# bzip2-1.0.8          | 247 KB    | : 100% 1.0/1 [00:02<00:00,  2.53s/it]
#
#
#
#
#
#
#
#
# bzip2-1.0.8          | 247 KB    | : 100% 1.0/1 [00:02<00:00,  2.53s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# libxcrypt-4.4.36     | 98 KB     | : 100% 1.0/1 [00:02<00:00,  2.62s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# libxcrypt-4.4.36     | 98 KB     | : 100% 1.0/1 [00:02<00:00,  2.62s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# wheel-0.45.1         | 61 KB     | : 100% 1.0/1 [00:02<00:00,  2.72s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# wheel-0.45.1         | 61 KB     | : 100% 1.0/1 [00:02<00:00,  2.72s/it]
#
#
#
#
#
#
#
#
#
#
#
# liblzma-5.6.3        | 109 KB    | : 100% 1.0/1 [00:02<00:00,  2.63s/it]
#
#
#
#
#
#
#
#
#
#
#
# liblzma-5.6.3        | 109 KB    | : 100% 1.0/1 [00:02<00:00,  2.63s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libzlib-1.3.1        | 60 KB     | : 100% 1.0/1 [00:02<00:00,  2.74s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libzlib-1.3.1        | 60 KB     | : 100% 1.0/1 [00:02<00:00,  2.74s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-ng-14.2.0     | 53 KB     | : 100% 1.0/1 [00:02<00:00,  2.82s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate myenv
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %%
# %%shell
# eval "$(conda shell.bash hook)"
# conda activate myenv
# conda install pytorch cudatoolkit=10.1 -c pytorch
# conda install pip
# cd QuestEval
# python3 -m pip install -e .
# Out:
# Channels:
#  - pytorch
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/myenv
#
#   added / updated specs:
#     - cudatoolkit=10.1
#     - pytorch
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-4.5          |       2_kmp_llvm           6 KB  conda-forge
#     blas-2.116                 |              mkl          13 KB  conda-forge
#     blas-devel-3.9.0           |   16_linux64_mkl          12 KB  conda-forge
#     cpython-3.9.21             |   py39hd8ed1ab_1          47 KB  conda-forge
#     cudatoolkit-10.1.243       |      h6d9799a_13       334.6 MB  conda-forge
#     filelock-3.16.1            |     pyhd8ed1ab_1          17 KB  conda-forge
#     gmp-6.3.0                  |       hac33072_2         449 KB  conda-forge
#     gmpy2-2.1.5                |   py39h7196dd7_3         199 KB  conda-forge
#     jinja2-3.1.4               |     pyhd8ed1ab_1         108 KB  conda-forge
#     libblas-3.9.0              |   16_linux64_mkl          13 KB  conda-forge
#     libcblas-3.9.0             |   16_linux64_mkl          12 KB  conda-forge
#     libgfortran-14.2.0         |       h69a702a_1          53 KB  conda-forge
#     libgfortran-ng-14.2.0      |       h69a702a_1          53 KB  conda-forge
#     libgfortran5-14.2.0        |       hd5240d6_1         1.4 MB  conda-forge
#     libhwloc-2.11.2            |default_h0d58e46_1001         2.3 MB  conda-forge
#     liblapack-3.9.0            |   16_linux64_mkl          12 KB  conda-forge
#     liblapacke-3.9.0           |   16_linux64_mkl          12 KB  conda-forge
#     libstdcxx-14.2.0           |       hc0a3c3a_1         3.7 MB  conda-forge
#     libstdcxx-ng-14.2.0        |       h4852527_1          53 KB  conda-forge
#     libxml2-2.13.5             |       h0d44e9d_1         674 KB  conda-forge
#     llvm-openmp-15.0.7         |       h0cdce71_0         3.1 MB  conda-forge
#     markupsafe-3.0.2           |   py39h9399b63_1          22 KB  conda-forge
#     mkl-2022.1.0               |     h84fe81f_915       199.6 MB  conda-forge
#     mkl-devel-2022.1.0         |     ha770c72_916          25 KB  conda-forge
#     mkl-include-2022.1.0       |     h84fe81f_915         745 KB  conda-forge
#     mpc-1.3.1                  |       h24ddda3_1         114 KB  conda-forge
#     mpfr-4.2.1                 |       h90cbb55_3         620 KB  conda-forge
#     mpmath-1.3.0               |     pyhd8ed1ab_1         429 KB  conda-forge
#     networkx-3.2.1             |     pyhd8ed1ab_0         1.1 MB  conda-forge
#     python_abi-3.9             |           5_cp39           6 KB  conda-forge
#     pytorch-2.5.1              |      py3.9_cpu_0        87.8 MB  pytorch
#     pytorch-mutex-1.0          |              cpu           3 KB  pytorch
#     pyyaml-6.0.2               |   py39h8cd3c5a_1         177 KB  conda-forge
#     sympy-1.13.3               |   pyh2585a3b_104         4.4 MB  conda-forge
#     tbb-2021.13.0              |       hceb3a55_1         172 KB  conda-forge
#     typing_extensions-4.12.2   |     pyha770c72_1          39 KB  conda-forge
#     yaml-0.2.5                 |       h7f98852_2          87 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       642.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   blas               conda-forge/linux-64::blas-2.116-mkl
#   blas-devel         conda-forge/linux-64::blas-devel-3.9.0-16_linux64_mkl
#   cpython            conda-forge/noarch::cpython-3.9.21-py39hd8ed1ab_1
#   cudatoolkit        conda-forge/linux-64::cudatoolkit-10.1.243-h6d9799a_13
#   filelock           conda-forge/noarch::filelock-3.16.1-pyhd8ed1ab_1
#   gmp                conda-forge/linux-64::gmp-6.3.0-hac33072_2
#   gmpy2              conda-forge/linux-64::gmpy2-2.1.5-py39h7196dd7_3
#   jinja2             conda-forge/noarch::jinja2-3.1.4-pyhd8ed1ab_1
#   libblas            conda-forge/linux-64::libblas-3.9.0-16_linux64_mkl
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-16_linux64_mkl
#   libgfortran        conda-forge/linux-64::libgfortran-14.2.0-h69a702a_1
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-14.2.0-h69a702a_1
#   libgfortran5       conda-forge/linux-64::libgfortran5-14.2.0-hd5240d6_1
#   libhwloc           conda-forge/linux-64::libhwloc-2.11.2-default_h0d58e46_1001
#   libiconv           conda-forge/linux-64::libiconv-1.17-hd590300_2
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-16_linux64_mkl
#   liblapacke         conda-forge/linux-64::liblapacke-3.9.0-16_linux64_mkl
#   libstdcxx          conda-forge/linux-64::libstdcxx-14.2.0-hc0a3c3a_1
#   libstdcxx-ng       conda-forge/linux-64::libstdcxx-ng-14.2.0-h4852527_1
#   libxml2            conda-forge/linux-64::libxml2-2.13.5-h0d44e9d_1
#   llvm-openmp        conda-forge/linux-64::llvm-openmp-15.0.7-h0cdce71_0
#   markupsafe         conda-forge/linux-64::markupsafe-3.0.2-py39h9399b63_1
#   mkl                conda-forge/linux-64::mkl-2022.1.0-h84fe81f_915
#   mkl-devel          conda-forge/linux-64::mkl-devel-2022.1.0-ha770c72_916
#   mkl-include        conda-forge/linux-64::mkl-include-2022.1.0-h84fe81f_915
#   mpc                conda-forge/linux-64::mpc-1.3.1-h24ddda3_1
#   mpfr               conda-forge/linux-64::mpfr-4.2.1-h90cbb55_3
#   mpmath             conda-forge/noarch::mpmath-1.3.0-pyhd8ed1ab_1
#   networkx           conda-forge/noarch::networkx-3.2.1-pyhd8ed1ab_0
#   python_abi         conda-forge/linux-64::python_abi-3.9-5_cp39
#   pytorch            pytorch/linux-64::pytorch-2.5.1-py3.9_cpu_0
#   pytorch-mutex      pytorch/noarch::pytorch-mutex-1.0-cpu
#   pyyaml             conda-forge/linux-64::pyyaml-6.0.2-py39h8cd3c5a_1
#   sympy              conda-forge/noarch::sympy-1.13.3-pyh2585a3b_104
#   tbb                conda-forge/linux-64::tbb-2021.13.0-hceb3a55_1
#   typing_extensions  conda-forge/noarch::typing_extensions-4.12.2-pyha770c72_1
#   yaml               conda-forge/linux-64::yaml-0.2.5-h7f98852_2
#
# The following packages will be DOWNGRADED:
#
#   _openmp_mutex                                   4.5-2_gnu --> 4.5-2_kmp_llvm
#
#
#
# Downloading and Extracting Packages:
# cudatoolkit-10.1.243 | 334.6 MB  | :   0% 0/1 [00:00<?, ?it/s]
# mkl-2022.1.0         | 199.6 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
# pytorch-2.5.1        | 87.8 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
# sympy-1.13.3         | 4.4 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# libstdcxx-14.2.0     | 3.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# llvm-openmp-15.0.7   | 3.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# libhwloc-2.11.2      | 2.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# libgfortran5-14.2.0  | 1.4 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# networkx-3.2.1       | 1.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# mkl-include-2022.1.0 | 745 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# libxml2-2.13.5       | 674 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# mpfr-4.2.1           | 620 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# gmp-6.3.0            | 449 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# mpmath-1.3.0         | 429 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# gmpy2-2.1.5          | 199 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyyaml-6.0.2         | 177 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tbb-2021.13.0        | 172 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mpc-1.3.1            | 114 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jinja2-3.1.4         | 108 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# libstdcxx-14.2.0     | 3.7 MB    | :   0% 0.004207828296772089/1 [00:00<00:33, 33.56s/it]
#
#
# sympy-1.13.3         | 4.4 MB    | :   0% 0.003591889922955452/1 [00:00<00:41, 42.09s/it]
#
# pytorch-2.5.1        | 87.8 MB   | :   0% 0.00017788887532548946/1 [00:00<15:00, 900.63s/it]
# mkl-2022.1.0         | 199.6 MB  | :   0% 7.826994939611777e-05/1 [00:00<40:58, 2459.08s/it]
#
#
#
# libstdcxx-14.2.0     | 3.7 MB    | :  28% 0.2777166675869579/1 [00:00<00:00,  1.36it/s]
#
#
# sympy-1.13.3         | 4.4 MB    | :  15% 0.15445126668708442/1 [00:00<00:01,  1.34s/it]
#
# pytorch-2.5.1        | 87.8 MB   | :   1% 0.006403999511717621/1 [00:00<00:33, 33.50s/it]
# cudatoolkit-10.1.243 | 334.6 MB  | :   0% 4.670449902124371e-05/1 [00:00<1:46:23, 6384.15s/it]
#
# pytorch-2.5.1        | 87.8 MB   | :   5% 0.05283299597167037/1 [00:00<00:04,  5.03s/it]
#
#
#
#
# llvm-openmp-15.0.7   | 3.1 MB    | :   1% 0.005012289041185573/1 [00:00<01:14, 75.29s/it]
# cudatoolkit-10.1.243 | 334.6 MB  | :   0% 0.0009340899804248742/1 [00:00<05:35, 336.04s/it]
#
# pytorch-2.5.1        | 87.8 MB   | :   9% 0.08805499328611728/1 [00:00<00:03,  4.00s/it]
# cudatoolkit-10.1.243 | 334.6 MB  | :   0% 0.003222610432465816/1 [00:00<01:47, 108.26s/it]
#
#
#
#
#
# libhwloc-2.11.2      | 2.3 MB    | :   1% 0.006761307362165732/1 [00:00<01:15, 76.09s/it]
#
# cudatoolkit-10.1.243 | 334.6 MB  | :   1% 0.009527717800333717/1 [00:00<00:38, 38.77s/it]
# mkl-2022.1.0         | 199.6 MB  | :   6% 0.056745713312185385/1 [00:00<00:07,  7.95s/it]
#
#
#
#
#
#
# libgfortran5-14.2.0  | 1.4 MB    | :   1% 0.011201624454327605/1 [00:00<00:57, 57.79s/it]
#
# cudatoolkit-10.1.243 | 334.6 MB  | :   2% 0.020316457074241016/1 [00:00<00:19, 19.94s/it]
# mkl-2022.1.0         | 199.6 MB  | :   7% 0.07482607162268859/1 [00:00<00:06,  7.21s/it]
#
#
#
#
#
#
#
# networkx-3.2.1       | 1.1 MB    | :   1% 0.01425250880342951/1 [00:00<00:50, 51.30s/it]
#
# pytorch-2.5.1        | 87.8 MB   | :  21% 0.20724053975419524/1 [00:00<00:02,  3.02s/it]
#
#
#
#
#
#
#
#
# cudatoolkit-10.1.243 | 334.6 MB  | :   3% 0.028629857900022395/1 [00:00<00:16, 16.65s/it]
# mkl-2022.1.0         | 199.6 MB  | :   9% 0.09196719054043838/1 [00:00<00:06,  7.10s/it]
#
#
#
#
#
#
#
#
#
# libxml2-2.13.5       | 674 KB    | :   2% 0.023745168429244935/1 [00:00<00:35, 36.13s/it]
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-10.1.243 | 334.6 MB  | :   4% 0.03923177917784472/1 [00:00<00:13, 13.69s/it]
#
# pytorch-2.5.1        | 87.8 MB   | :  25% 0.2545589805907754/1 [00:00<00:02,  2.83s/it]
# mkl-2022.1.0         | 199.6 MB  | :  11% 0.11247391728222124/1 [00:00<00:05,  6.43s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# mpmath-1.3.0         | 429 KB    | :   4% 0.03726134567494115/1 [00:00<00:24, 25.79s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-10.1.243 | 334.6 MB  | :   5% 0.05030074544587948/1 [00:01<00:11, 11.98s/it]
#
# pytorch-2.5.1        | 87.8 MB   | :  30% 0.2977859772948694/1 [00:01<00:01,  2.73s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# gmpy2-2.1.5          | 199 KB    | :   8% 0.08025039062308668/1 [00:01<00:11, 12.76s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyyaml-6.0.2         | 177 KB    | :   9% 0.09017458115932457/1 [00:01<00:10, 11.42s/it]
# mkl-2022.1.0         | 199.6 MB  | :  13% 0.13282410412521187/1 [00:01<00:05,  6.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tbb-2021.13.0        | 172 KB    | :   9% 0.09311524603021244/1 [00:01<00:10, 11.69s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-10.1.243 | 334.6 MB  | :   6% 0.061696643207062946/1 [00:01<00:10, 10.81s/it]
#
# pytorch-2.5.1        | 87.8 MB   | :  35% 0.345993862508077/1 [00:01<00:01,  2.50s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jinja2-3.1.4         | 108 KB    | :  15% 0.14765282121067383/1 [00:01<00:06,  7.75s/it]
# mkl-2022.1.0         | 199.6 MB  | :  16% 0.15520930965250154/1 [00:01<00:04,  5.70s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# pytorch-2.5.1        | 87.8 MB   | :  39% 0.39064397021477487/1 [00:01<00:01,  2.42s/it]
#
#
#
# libstdcxx-14.2.0     | 3.7 MB    | : 100% 1.0/1 [00:01<00:00,  1.22s/it]
#
#
#
# cudatoolkit-10.1.243 | 334.6 MB  | :   8% 0.07598821990756352/1 [00:01<00:08,  9.69s/it]
# mkl-2022.1.0         | 199.6 MB  | :  17% 0.17297658816542028/1 [00:01<00:05,  6.07s/it]
#
# cudatoolkit-10.1.243 | 334.6 MB  | :   9% 0.08649673218734336/1 [00:01<00:10, 11.77s/it]
# mkl-2022.1.0         | 199.6 MB  | :  19% 0.18972635733618948/1 [00:01<00:05,  6.57s/it]
#
# cudatoolkit-10.1.243 | 334.6 MB  | :  10% 0.09784592544950557/1 [00:01<00:09, 10.95s/it]
# mkl-2022.1.0         | 199.6 MB  | :  21% 0.20851114519125774/1 [00:01<00:05,  6.33s/it]
#
# cudatoolkit-10.1.243 | 334.6 MB  | :  11% 0.10751375674690303/1 [00:01<00:09, 10.89s/it]
# mkl-2022.1.0         | 199.6 MB  | :  22% 0.22455648481746188/1 [00:01<00:04,  6.34s/it]
#
# cudatoolkit-10.1.243 | 334.6 MB  | :  12% 0.11708817904625798/1 [00:01<00:09, 10.82s/it]
# mkl-2022.1.0         | 199.6 MB  | :  24% 0.2405235544942699/1 [00:01<00:04,  6.51s/it]
#
# pytorch-2.5.1        | 87.8 MB   | :  58% 0.5831197333169544/1 [00:01<00:01,  2.99s/it]
# cudatoolkit-10.1.243 | 334.6 MB  | :  13% 0.1266158968465917/1 [00:01<00:10, 11.64s/it]
#
# cudatoolkit-10.1.243 | 334.6 MB  | :  14% 0.13628372814398915/1 [00:01<00:09, 11.33s/it]
# mkl-2022.1.0         | 199.6 MB  | :  27% 0.27245769384788593/1 [00:01<00:04,  6.58s/it]
#
#
#
#
# llvm-openmp-15.0.7   | 3.1 MB    | : 100% 1.0/1 [00:01<00:00,  1.87s/it]
#
#
#
#
# llvm-openmp-15.0.7   | 3.1 MB    | : 100% 1.0/1 [00:01<00:00,  1.87s/it]
#
# cudatoolkit-10.1.243 | 334.6 MB  | :  15% 0.14814667089538505/1 [00:02<00:08, 10.53s/it]
# mkl-2022.1.0         | 199.6 MB  | :  29% 0.29304269053906495/1 [00:02<00:04,  6.03s/it]
#
# cudatoolkit-10.1.243 | 334.6 MB  | :  16% 0.15800132018886748/1 [00:02<00:08, 10.62s/it]
# mkl-2022.1.0         | 199.6 MB  | :  31% 0.3119057483435293/1 [00:02<00:04,  5.93s/it]
#
# pytorch-2.5.1        | 87.8 MB   | :  75% 0.7473111652423813/1 [00:02<00:00,  2.57s/it]
# cudatoolkit-10.1.243 | 334.6 MB  | :  17% 0.17028460343145457/1 [00:02<00:08, 10.04s/it]
#
# pytorch-2.5.1        | 87.8 MB   | :  79% 0.7892929398191968/1 [00:02<00:00,  2.57s/it]
# cudatoolkit-10.1.243 | 334.6 MB  | :  18% 0.18135356969948932/1 [00:02<00:08,  9.87s/it]
#
# pytorch-2.5.1        | 87.8 MB   | :  84% 0.8396354915363102/1 [00:02<00:00,  2.41s/it]
# cudatoolkit-10.1.243 | 334.6 MB  | :  19% 0.19410389793228885/1 [00:02<00:07,  9.30s/it]
#
# pytorch-2.5.1        | 87.8 MB   | :  89% 0.8949589317625375/1 [00:02<00:00,  2.28s/it]
# cudatoolkit-10.1.243 | 334.6 MB  | :  21% 0.2075080891513858/1 [00:02<00:06,  8.71s/it]
#
# pytorch-2.5.1        | 87.8 MB   | :  95% 0.9501044831134392/1 [00:02<00:00,  2.17s/it]
# cudatoolkit-10.1.243 | 334.6 MB  | :  22% 0.2235277323156724/1 [00:02<00:06,  8.11s/it]
# cudatoolkit-10.1.243 | 334.6 MB  | :  24% 0.23856658100051287/1 [00:02<00:05,  7.83s/it]
# cudatoolkit-10.1.243 | 334.6 MB  | :  25% 0.2513636137323337/1 [00:02<00:05,  7.86s/it]
# cudatoolkit-10.1.243 | 334.6 MB  | :  26% 0.2641139419651332/1 [00:03<00:06,  8.67s/it]
# cudatoolkit-10.1.243 | 334.6 MB  | :  28% 0.27583677121946537/1 [00:03<00:06,  8.80s/it]
# cudatoolkit-10.1.243 | 334.6 MB  | :  29% 0.2873260779786913/1 [00:03<00:06,  9.10s/it]
# cudatoolkit-10.1.243 | 334.6 MB  | :  30% 0.3011973141880007/1 [00:03<00:05,  8.57s/it]
# cudatoolkit-10.1.243 | 334.6 MB  | :  31% 0.3129668479413541/1 [00:03<00:05,  8.59s/it]
#
#
#
#
#
# libhwloc-2.11.2      | 2.3 MB    | : 100% 1.0/1 [00:03<00:00,  3.31s/it]
#
#
#
#
#
# libhwloc-2.11.2      | 2.3 MB    | : 100% 1.0/1 [00:03<00:00,  3.31s/it]
# cudatoolkit-10.1.243 | 334.6 MB  | :  32% 0.32468967719568625/1 [00:03<00:05,  8.73s/it]
# cudatoolkit-10.1.243 | 334.6 MB  | :  34% 0.33739330092946457/1 [00:03<00:05,  8.56s/it]
# cudatoolkit-10.1.243 | 334.6 MB  | :  35% 0.3491161301837967/1 [00:03<00:05,  8.63s/it]
# cudatoolkit-10.1.243 | 334.6 MB  | :  36% 0.36074555044008644/1 [00:03<00:05,  8.86s/it]
#
#
#
#
#
#
# libgfortran5-14.2.0  | 1.4 MB    | : 100% 1.0/1 [00:03<00:00,  3.70s/it]
#
#
#
#
#
#
# libgfortran5-14.2.0  | 1.4 MB    | : 100% 1.0/1 [00:03<00:00,  3.70s/it]
# cudatoolkit-10.1.243 | 334.6 MB  | :  37% 0.37209474370224865/1 [00:03<00:05,  8.96s/it]
# cudatoolkit-10.1.243 | 334.6 MB  | :  39% 0.3941859717392969/1 [00:04<00:05,  9.62s/it]
# cudatoolkit-10.1.243 | 334.6 MB  | :  40% 0.40469448401907676/1 [00:04<00:05,  9.76s/it]
# mkl-2022.1.0         | 199.6 MB  | :  71% 0.7133523187962173/1 [00:04<00:02,  8.52s/it]
# cudatoolkit-10.1.243 | 334.6 MB  | :  41% 0.4149694738037504/1 [00:06<00:34, 59.49s/it]
# cudatoolkit-10.1.243 | 334.6 MB  | :  42% 0.42234878464910686/1 [00:07<00:46, 80.93s/it]
# mkl-2022.1.0         | 199.6 MB  | :  74% 0.7437993291113072/1 [00:07<00:12, 47.40s/it]
#
#
#
#
#
#
#
# networkx-3.2.1       | 1.1 MB    | : 100% 1.0/1 [00:07<00:00,  7.21s/it]
#
#
#
#
#
#
#
# cudatoolkit-10.1.243 | 334.6 MB  | :  44% 0.4370139973417774/1 [00:07<00:29, 52.04s/it]
# mkl-2022.1.0         | 199.6 MB  | :  76% 0.7648539454988629/1 [00:07<00:06, 29.46s/it]
#
#
# sympy-1.13.3         | 4.4 MB    | : 100% 1.0/1 [00:07<00:00,  7.81s/it]
#
#
# sympy-1.13.3         | 4.4 MB    | : 100% 1.0/1 [00:07<00:00,  7.81s/it]
#
#
#
#
#
#
#
#
#
#
# mpfr-4.2.1           | 620 KB    | : 100% 1.0/1 [00:07<00:00,  7.41s/it]
#
#
#
#
#
#
#
#
#
#
# mpfr-4.2.1           | 620 KB    | : 100% 1.0/1 [00:07<00:00,  7.41s/it]
# cudatoolkit-10.1.243 | 334.6 MB  | :  45% 0.4451405801714738/1 [00:07<00:25, 45.24s/it]
#
#
#
#
#
#
#
#
#
# libxml2-2.13.5       | 674 KB    | : 100% 1.0/1 [00:07<00:00,  7.51s/it]
#
#
#
#
#
#
#
#
#
# libxml2-2.13.5       | 674 KB    | : 100% 1.0/1 [00:07<00:00,  7.51s/it]
# cudatoolkit-10.1.243 | 334.6 MB  | :  45% 0.45387432148844636/1 [00:07<00:19, 36.26s/it]
# cudatoolkit-10.1.243 | 334.6 MB  | :  47% 0.46984726015371175/1 [00:07<00:12, 23.96s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# mpmath-1.3.0         | 429 KB    | : 100% 1.0/1 [00:07<00:00,  7.71s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# mpmath-1.3.0         | 429 KB    | : 100% 1.0/1 [00:07<00:00,  7.71s/it]
# cudatoolkit-10.1.243 | 334.6 MB  | :  49% 0.48577349431995587/1 [00:07<00:08, 17.45s/it]
#
#
#
#
#
#
#
#
#
#
#
# gmp-6.3.0            | 449 KB    | : 100% 1.0/1 [00:07<00:00,  7.79s/it]
#
#
#
#
#
#
#
#
#
#
#
# gmp-6.3.0            | 449 KB    | : 100% 1.0/1 [00:07<00:00,  7.79s/it]
# cudatoolkit-10.1.243 | 334.6 MB  | :  50% 0.5001117755194776/1 [00:08<00:07, 14.11s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# gmpy2-2.1.5          | 199 KB    | : 100% 1.0/1 [00:08<00:00,  7.94s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# gmpy2-2.1.5          | 199 KB    | : 100% 1.0/1 [00:08<00:00,  7.94s/it]
# cudatoolkit-10.1.243 | 334.6 MB  | :  52% 0.5155242601964881/1 [00:08<00:05, 11.59s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyyaml-6.0.2         | 177 KB    | : 100% 1.0/1 [00:08<00:00,  8.10s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyyaml-6.0.2         | 177 KB    | : 100% 1.0/1 [00:08<00:00,  8.10s/it]
# mkl-2022.1.0         | 199.6 MB  | :  90% 0.8966605402819252/1 [00:08<00:00,  5.73s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-10.1.243 | 334.6 MB  | :  53% 0.5318241303549022/1 [00:08<00:04,  9.83s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mpc-1.3.1            | 114 KB    | : 100% 1.0/1 [00:08<00:00,  8.27s/it]
# mkl-2022.1.0         | 199.6 MB  | :  92% 0.921080764493514/1 [00:08<00:00,  5.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tbb-2021.13.0        | 172 KB    | : 100% 1.0/1 [00:08<00:00,  8.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-10.1.243 | 334.6 MB  | :  55% 0.5460690025563815/1 [00:08<00:04,  9.06s/it]
# mkl-2022.1.0         | 199.6 MB  | :  94% 0.9439355897171803/1 [00:08<00:00,  5.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jinja2-3.1.4         | 108 KB    | : 100% 1.0/1 [00:08<00:00,  8.49s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-10.1.243 | 334.6 MB  | :  56% 0.5601270567617759/1 [00:08<00:03,  8.65s/it]
# mkl-2022.1.0         | 199.6 MB  | :  97% 0.9746956798298546/1 [00:08<00:00,  4.46s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-10.1.243 | 334.6 MB  | :  58% 0.5805836273330806/1 [00:08<00:03,  7.25s/it]
# mkl-2022.1.0         | 199.6 MB  | : 100% 0.9993507138896317/1 [00:08<00:00,  4.38s/it]
#
#
#
#
#
#
#
#
# mkl-include-2022.1.0 | 745 KB    | : 100% 1.0/1 [00:08<00:00,  8.49s/it]
#
#
#
#
#
#
#
#
# cudatoolkit-10.1.243 | 334.6 MB  | :  98% 0.9782724364989708/1 [00:10<00:00,  4.53s/it]
#
# pytorch-2.5.1        | 87.8 MB   | : 100% 1.0/1 [00:43<00:00, 247.52s/it]
#
# cudatoolkit-10.1.243 | 334.6 MB  | : 100% 1.0/1 [00:53<00:00,  4.53s/it]
# mkl-2022.1.0         | 199.6 MB  | : 100% 1.0/1 [01:02<00:00,  4.38s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# / By downloading and using the CUDA Toolkit conda packages, you accept the terms and conditions of the CUDA End User License Agreement (EULA): https://docs.nvidia.com/cuda/eula/index.html
#
# done
# Channels:
#  - conda-forge
#  - pytorch
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# # All requested packages already installed.
#
# Obtaining file:///content/QuestEval
#   Preparing metadata (setup.py) ... done
# Collecting pytest==6.2.4 (from questeval==0.2.4)
#   Downloading pytest-6.2.4-py3-none-any.whl.metadata (7.3 kB)
# Collecting transformers==4.8.1 (from questeval==0.2.4)
#   Downloading transformers-4.8.1-py3-none-any.whl.metadata (48 kB)
# Collecting sentencepiece==0.1.95 (from questeval==0.2.4)
#   Downloading sentencepiece-0.1.95-cp39-cp39-manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting datasets==1.7.0 (from questeval==0.2.4)
#   Downloading datasets-1.7.0-py3-none-any.whl.metadata (9.2 kB)
# Collecting bert_score==0.3.9 (from questeval==0.2.4)
#   Downloading bert_score-0.3.9-py3-none-any.whl.metadata (13 kB)
# Collecting Unidecode==1.2.0 (from questeval==0.2.4)
#   Downloading Unidecode-1.2.0-py2.py3-none-any.whl.metadata (13 kB)
# Collecting spacy==3.0.6 (from questeval==0.2.4)
#   Downloading spacy-3.0.6-cp39-cp39-manylinux2014_x86_64.whl.metadata (17 kB)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from bert_score==0.3.9->questeval==0.2.4) (2.5.1)
# Collecting numpy (from bert_score==0.3.9->questeval==0.2.4)
#   Downloading numpy-2.0.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Collecting pandas>=1.0.1 (from bert_score==0.3.9->questeval==0.2.4)
#   Downloading pandas-2.2.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
# Collecting requests (from bert_score==0.3.9->questeval==0.2.4)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting tqdm>=4.31.1 (from bert_score==0.3.9->questeval==0.2.4)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting matplotlib (from bert_score==0.3.9->questeval==0.2.4)
#   Downloading matplotlib-3.9.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting pyarrow<4.0.0,>=1.0.0 (from datasets==1.7.0->questeval==0.2.4)
#   Downloading pyarrow-3.0.0-cp39-cp39-manylinux2014_x86_64.whl.metadata (2.8 kB)
# Collecting dill (from datasets==1.7.0->questeval==0.2.4)
#   Downloading dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Collecting tqdm>=4.31.1 (from bert_score==0.3.9->questeval==0.2.4)
#   Downloading tqdm-4.49.0-py2.py3-none-any.whl.metadata (55 kB)
# Collecting xxhash (from datasets==1.7.0->questeval==0.2.4)
#   Downloading xxhash-3.5.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets==1.7.0->questeval==0.2.4)
#   Downloading multiprocess-0.70.17-py39-none-any.whl.metadata (7.2 kB)
# Collecting fsspec (from datasets==1.7.0->questeval==0.2.4)
#   Downloading fsspec-2024.10.0-py3-none-any.whl.metadata (11 kB)
# Collecting huggingface-hub<0.1.0 (from datasets==1.7.0->questeval==0.2.4)
#   Downloading huggingface_hub-0.0.19-py3-none-any.whl.metadata (6.3 kB)
# Collecting packaging (from datasets==1.7.0->questeval==0.2.4)
#   Downloading packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting attrs>=19.2.0 (from pytest==6.2.4->questeval==0.2.4)
#   Downloading attrs-24.2.0-py3-none-any.whl.metadata (11 kB)
# Collecting iniconfig (from pytest==6.2.4->questeval==0.2.4)
#   Downloading iniconfig-2.0.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting pluggy<1.0.0a1,>=0.12 (from pytest==6.2.4->questeval==0.2.4)
#   Downloading pluggy-0.13.1-py2.py3-none-any.whl.metadata (15 kB)
# Collecting py>=1.8.2 (from pytest==6.2.4->questeval==0.2.4)
#   Downloading py-1.11.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting toml (from pytest==6.2.4->questeval==0.2.4)
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.4 (from spacy==3.0.6->questeval==0.2.4)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy==3.0.6->questeval==0.2.4)
#   Downloading murmurhash-1.0.11-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.0 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy==3.0.6->questeval==0.2.4)
#   Downloading cymem-2.0.10-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.4 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy==3.0.6->questeval==0.2.4)
#   Downloading preshed-3.0.9-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.2 kB)
# Collecting thinc<8.1.0,>=8.0.3 (from spacy==3.0.6->questeval==0.2.4)
#   Downloading thinc-8.0.17-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Collecting blis<0.8.0,>=0.4.0 (from spacy==3.0.6->questeval==0.2.4)
#   Downloading blis-0.7.11-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.4 kB)
# Collecting wasabi<1.1.0,>=0.8.1 (from spacy==3.0.6->questeval==0.2.4)
#   Downloading wasabi-0.10.1-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.1 (from spacy==3.0.6->questeval==0.2.4)
#   Downloading srsly-2.5.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Collecting catalogue<2.1.0,>=2.0.3 (from spacy==3.0.6->questeval==0.2.4)
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting typer<0.4.0,>=0.3.0 (from spacy==3.0.6->questeval==0.2.4)
#   Downloading typer-0.3.2-py3-none-any.whl.metadata (12 kB)
# Collecting pathy>=0.3.5 (from spacy==3.0.6->questeval==0.2.4)
#   Downloading pathy-0.11.0-py3-none-any.whl.metadata (16 kB)
# Collecting pydantic<1.8.0,>=1.7.1 (from spacy==3.0.6->questeval==0.2.4)
#   Downloading pydantic-1.7.4-cp39-cp39-manylinux2014_x86_64.whl.metadata (85 kB)
# Requirement already satisfied: jinja2 in /usr/local/envs/myenv/lib/python3.9/site-packages (from spacy==3.0.6->questeval==0.2.4) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/envs/myenv/lib/python3.9/site-packages (from spacy==3.0.6->questeval==0.2.4) (75.6.0)
# Requirement already satisfied: filelock in /usr/local/envs/myenv/lib/python3.9/site-packages (from transformers==4.8.1->questeval==0.2.4) (3.16.1)
# Collecting huggingface-hub<0.1.0 (from datasets==1.7.0->questeval==0.2.4)
#   Downloading huggingface_hub-0.0.12-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pyyaml in /usr/local/envs/myenv/lib/python3.9/site-packages (from transformers==4.8.1->questeval==0.2.4) (6.0.2)
# Collecting regex!=2019.12.17 (from transformers==4.8.1->questeval==0.2.4)
#   Downloading regex-2024.11.6-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# Collecting sacremoses (from transformers==4.8.1->questeval==0.2.4)
#   Downloading sacremoses-0.1.1-py3-none-any.whl.metadata (8.3 kB)
# Collecting tokenizers<0.11,>=0.10.1 (from transformers==4.8.1->questeval==0.2.4)
#   Downloading tokenizers-0.10.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (5.8 kB)
# Requirement already satisfied: typing-extensions in /usr/local/envs/myenv/lib/python3.9/site-packages (from huggingface-hub<0.1.0->datasets==1.7.0->questeval==0.2.4) (4.12.2)
# Collecting python-dateutil>=2.8.2 (from pandas>=1.0.1->bert_score==0.3.9->questeval==0.2.4)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas>=1.0.1->bert_score==0.3.9->questeval==0.2.4)
#   Downloading pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=1.0.1->bert_score==0.3.9->questeval==0.2.4)
#   Downloading tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting smart-open<7.0.0,>=5.2.1 (from pathy>=0.3.5->spacy==3.0.6->questeval==0.2.4)
#   Downloading smart_open-6.4.0-py3-none-any.whl.metadata (21 kB)
# Collecting pathlib-abc==0.1.1 (from pathy>=0.3.5->spacy==3.0.6->questeval==0.2.4)
#   Downloading pathlib_abc-0.1.1-py3-none-any.whl.metadata (18 kB)
# Collecting charset-normalizer<4,>=2 (from requests->bert_score==0.3.9->questeval==0.2.4)
#   Downloading charset_normalizer-3.4.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests->bert_score==0.3.9->questeval==0.2.4)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->bert_score==0.3.9->questeval==0.2.4)
#   Downloading urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests->bert_score==0.3.9->questeval==0.2.4)
#   Downloading certifi-2024.8.30-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: networkx in /usr/local/envs/myenv/lib/python3.9/site-packages (from torch>=1.0.0->bert_score==0.3.9->questeval==0.2.4) (3.2.1)
# Collecting sympy==1.13.1 (from torch>=1.0.0->bert_score==0.3.9->questeval==0.2.4)
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from sympy==1.13.1->torch>=1.0.0->bert_score==0.3.9->questeval==0.2.4) (1.3.0)
# Collecting click<7.2.0,>=7.1.1 (from typer<0.4.0,>=0.3.0->spacy==3.0.6->questeval==0.2.4)
#   Downloading click-7.1.2-py2.py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from jinja2->spacy==3.0.6->questeval==0.2.4) (3.0.2)
# Collecting contourpy>=1.0.1 (from matplotlib->bert_score==0.3.9->questeval==0.2.4)
#   Downloading contourpy-1.3.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib->bert_score==0.3.9->questeval==0.2.4)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->bert_score==0.3.9->questeval==0.2.4)
#   Downloading fonttools-4.55.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (165 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->bert_score==0.3.9->questeval==0.2.4)
#   Downloading kiwisolver-1.4.7-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.3 kB)
# Collecting pillow>=8 (from matplotlib->bert_score==0.3.9->questeval==0.2.4)
#   Downloading pillow-11.0.0-cp39-cp39-manylinux_2_28_x86_64.whl.metadata (9.1 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib->bert_score==0.3.9->questeval==0.2.4)
#   Downloading pyparsing-3.2.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting importlib-resources>=3.2.0 (from matplotlib->bert_score==0.3.9->questeval==0.2.4)
#   Downloading importlib_resources-6.4.5-py3-none-any.whl.metadata (4.0 kB)
# Collecting joblib (from sacremoses->transformers==4.8.1->questeval==0.2.4)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting zipp>=3.1.0 (from importlib-resources>=3.2.0->matplotlib->bert_score==0.3.9->questeval==0.2.4)
#   Downloading zipp-3.21.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->pandas>=1.0.1->bert_score==0.3.9->questeval==0.2.4)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Downloading bert_score-0.3.9-py3-none-any.whl (59 kB)
# Downloading datasets-1.7.0-py3-none-any.whl (234 kB)
# Downloading pytest-6.2.4-py3-none-any.whl (280 kB)
# Downloading sentencepiece-0.1.95-cp39-cp39-manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 48.7 MB/s eta 0:00:00
# Downloading spacy-3.0.6-cp39-cp39-manylinux2014_x86_64.whl (12.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 73.4 MB/s eta 0:00:00
# Downloading transformers-4.8.1-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 99.4 MB/s eta 0:00:00
# Downloading Unidecode-1.2.0-py2.py3-none-any.whl (241 kB)
# Downloading huggingface_hub-0.0.12-py3-none-any.whl (37 kB)
# Downloading attrs-24.2.0-py3-none-any.whl (63 kB)
# Downloading blis-0.7.11-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 130.6 MB/s eta 0:00:00
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading cymem-2.0.10-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (208 kB)
# Downloading murmurhash-1.0.11-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (124 kB)
# Downloading numpy-2.0.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.5/19.5 MB 150.4 MB/s eta 0:00:00
# Downloading packaging-24.2-py3-none-any.whl (65 kB)
# Downloading pandas-2.2.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 163.5 MB/s eta 0:00:00
# Downloading pathy-0.11.0-py3-none-any.whl (47 kB)
# Downloading pathlib_abc-0.1.1-py3-none-any.whl (23 kB)
# Downloading pluggy-0.13.1-py2.py3-none-any.whl (18 kB)
# Downloading preshed-3.0.9-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (157 kB)
# Downloading py-1.11.0-py2.py3-none-any.whl (98 kB)
# Downloading pyarrow-3.0.0-cp39-cp39-manylinux2014_x86_64.whl (20.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.7/20.7 MB 49.7 MB/s eta 0:00:00
# Downloading pydantic-1.7.4-cp39-cp39-manylinux2014_x86_64.whl (10.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 117.3 MB/s eta 0:00:00
# Downloading regex-2024.11.6-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (780 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.9/780.9 kB 37.9 MB/s eta 0:00:00
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Downloading srsly-2.5.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 56.6 MB/s eta 0:00:00
# Downloading thinc-8.0.17-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (668 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 668.8/668.8 kB 36.0 MB/s eta 0:00:00
# Downloading tokenizers-0.10.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 78.9 MB/s eta 0:00:00
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 123.0 MB/s eta 0:00:00
# Downloading tqdm-4.49.0-py2.py3-none-any.whl (69 kB)
# Downloading typer-0.3.2-py3-none-any.whl (21 kB)
# Downloading wasabi-0.10.1-py3-none-any.whl (26 kB)
# Downloading dill-0.3.9-py3-none-any.whl (119 kB)
# Downloading fsspec-2024.10.0-py3-none-any.whl (179 kB)
# Downloading iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Downloading matplotlib-3.9.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 151.9 MB/s eta 0:00:00
# Downloading multiprocess-0.70.17-py39-none-any.whl (133 kB)
# Downloading sacremoses-0.1.1-py3-none-any.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 44.8 MB/s eta 0:00:00
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading xxhash-3.5.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (193 kB)
# Downloading certifi-2024.8.30-py3-none-any.whl (167 kB)
# Downloading charset_normalizer-3.4.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
# Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Downloading contourpy-1.3.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (321 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.55.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 134.2 MB/s eta 0:00:00
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading importlib_resources-6.4.5-py3-none-any.whl (36 kB)
# Downloading kiwisolver-1.4.7-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 75.9 MB/s eta 0:00:00
# Downloading pillow-11.0.0-cp39-cp39-manylinux_2_28_x86_64.whl (4.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 108.7 MB/s eta 0:00:00
# Downloading pyparsing-3.2.0-py3-none-any.whl (106 kB)
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Downloading pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Downloading smart_open-6.4.0-py3-none-any.whl (57 kB)
# Downloading tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Downloading urllib3-2.2.3-py3-none-any.whl (126 kB)
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Downloading zipp-3.21.0-py3-none-any.whl (9.6 kB)
# Installing collected packages: wasabi, tokenizers, sentencepiece, pytz, cymem, zipp, xxhash, urllib3, Unidecode, tzdata, tqdm, toml, sympy, spacy-legacy, smart-open, six, regex, pyparsing, pydantic, py, pluggy, pillow, pathlib-abc, packaging, numpy, murmurhash, kiwisolver, joblib, iniconfig, idna, fsspec, fonttools, dill, cycler, click, charset-normalizer, certifi, catalogue, attrs, typer, srsly, sacremoses, requests, python-dateutil, pytest, pyarrow, preshed, multiprocess, importlib-resources, contourpy, blis, thinc, pathy, pandas, matplotlib, huggingface-hub, transformers, spacy, datasets, bert_score, questeval
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.3
#     Uninstalling sympy-1.13.3:
#       Successfully uninstalled sympy-1.13.3
#   DEPRECATION: Legacy editable install of questeval==0.2.4 from file:///content/QuestEval (setup.py develop) is deprecated. pip 25.0 will enforce this behaviour change. A possible replacement is to add a pyproject.toml or enable --use-pep517, and use setuptools >= 64. If the resulting installation is not behaving as expected, try using --config-settings editable_mode=compat. Please consult the setuptools documentation for more information. Discussion can be found at https://github.com/pypa/pip/issues/11457
#   Running setup.py develop for questeval
# Successfully installed Unidecode-1.2.0 attrs-24.2.0 bert_score-0.3.9 blis-0.7.11 catalogue-2.0.10 certifi-2024.8.30 charset-normalizer-3.4.0 click-7.1.2 contourpy-1.3.0 cycler-0.12.1 cymem-2.0.10 datasets-1.7.0 dill-0.3.9 fonttools-4.55.3 fsspec-2024.10.0 huggingface-hub-0.0.12 idna-3.10 importlib-resources-6.4.5 iniconfig-2.0.0 joblib-1.4.2 kiwisolver-1.4.7 matplotlib-3.9.4 multiprocess-0.70.17 murmurhash-1.0.11 numpy-2.0.2 packaging-24.2 pandas-2.2.3 pathlib-abc-0.1.1 pathy-0.11.0 pillow-11.0.0 pluggy-0.13.1 preshed-3.0.9 py-1.11.0 pyarrow-3.0.0 pydantic-1.7.4 pyparsing-3.2.0 pytest-6.2.4 python-dateutil-2.9.0.post0 pytz-2024.2 questeval regex-2024.11.6 requests-2.32.3 sacremoses-0.1.1 sentencepiece-0.1.95 six-1.17.0 smart-open-6.4.0 spacy-3.0.6 spacy-legacy-3.0.12 srsly-2.5.0 sympy-1.13.1 thinc-8.0.17 tokenizers-0.10.3 toml-0.10.2 tqdm-4.49.0 transformers-4.8.1 typer-0.3.2 tzdata-2024.2 urllib3-2.2.3 wasabi-0.10.1 xxhash-3.5.0 zipp-3.21.0

# %%
# %%shell
# eval "$(conda shell.bash hook)"
# conda activate myenv
# pip install jsonlines
# conda install pytorch torchvision torchaudio pytorch-cuda=12.1 -c pytorch -c nvidia
# cd ../../../QuestEval
# ls
# python3 evaluate.py
# Out:
# Requirement already satisfied: jsonlines in /usr/local/envs/myenv/lib/python3.9/site-packages (4.0.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from jsonlines) (24.2.0)
# Channels:
#  - pytorch
#  - nvidia
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# # All requested packages already installed.
#
# evaluate.py  LICENSE.txt  questeval	      README.md		setup.py
# examples     MANIFEST.in  questeval.egg-info  requirements.txt	tests
# Downloading: 6.81kB [00:00, 13.4MB/s]
# WARNING:root:Downloading language model for the spaCy model.
# DEPRECATION: https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.0.0/en_core_web_sm-3.0.0-py3-none-any.whl#egg=en_core_web_sm==3.0.0 contains an egg fragment with a non-PEP 508 name pip 25.0 will enforce this behaviour change. A possible replacement is to use the req @ url syntax, and remove the egg fragment. Discussion can be found at https://github.com/pypa/pip/issues/11617
# Collecting en-core-web-sm==3.0.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.0.0/en_core_web_sm-3.0.0-py3-none-any.whl (13.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 128.6 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.1.0,>=3.0.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from en-core-web-sm==3.0.0) (3.0.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.4 in /usr/local/envs/myenv/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.12)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.0.11)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/envs/myenv/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/envs/myenv/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.9)
# Requirement already satisfied: thinc<8.1.0,>=8.0.3 in /usr/local/envs/myenv/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (8.0.17)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.7.11)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/envs/myenv/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/envs/myenv/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.5.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.3 in /usr/local/envs/myenv/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.10)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.3.2)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/envs/myenv/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.11.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (4.49.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.26.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.32.3)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in /usr/local/envs/myenv/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.7.4)
# Requirement already satisfied: jinja2 in /usr/local/envs/myenv/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/envs/myenv/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (75.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (24.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/envs/myenv/lib/python3.9/site-packages (from pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (6.4.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in /usr/local/envs/myenv/lib/python3.9/site-packages (from pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/envs/myenv/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/envs/myenv/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/envs/myenv/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/envs/myenv/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2024.8.30)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /usr/local/envs/myenv/lib/python3.9/site-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from jinja2->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.2)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.0.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# /usr/local/envs/myenv/lib/python3.9/site-packages/torch/__init__.py:1144: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at /opt/conda/conda-bld/pytorch_1729647350383/work/torch/csrc/tensor/python_tensor.cpp:432.)
#   _C._set_default_tensor_type(t)
# Downloading: 100% 792k/792k [00:00<00:00, 22.3MB/s]
# Downloading: 100% 1.79k/1.79k [00:00<00:00, 6.23MB/s]
# Downloading: 100% 1.91k/1.91k [00:00<00:00, 6.03MB/s]
# Downloading: 100% 1.41k/1.41k [00:00<00:00, 4.81MB/s]
# Downloading: 100% 892M/892M [00:14<00:00, 59.6MB/s]
# /usr/local/envs/myenv/lib/python3.9/site-packages/transformers/modeling_utils.py:1211: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(resolved_archive_file, map_location="cpu")
# Downloading: 100% 792k/792k [00:00<00:00, 19.2MB/s]
# Downloading: 100% 1.79k/1.79k [00:00<00:00, 6.71MB/s]
# Downloading: 100% 1.91k/1.91k [00:00<00:00, 6.65MB/s]
# Downloading: 100% 1.41k/1.41k [00:00<00:00, 4.81MB/s]
# Downloading: 100% 892M/892M [00:14<00:00, 62.2MB/s]
# word_swap
# Downloading: 100% 49.0/49.0 [00:00<00:00, 183kB/s]
# Downloading: 100% 625/625 [00:00<00:00, 2.26MB/s]
# Downloading: 100% 996k/996k [00:00<00:00, 13.3MB/s]
# Downloading: 100% 1.96M/1.96M [00:00<00:00, 7.62MB/s]
# Downloading: 100% 714M/714M [00:12<00:00, 57.3MB/s]
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertModel: ['cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 0
# 32
# 64
# 96
# 128
# 160
# 192
# 224
# 256
# 288
# 320
# 352
# 384
# 416
# 448
# 480
# 512
# 544
# 576
# 608
# 640
# 672
# 704
# 736
# 768
# 800
# 832
# 864
# 896
# 928
# 960
# 992
# 1024
# 1056
# 1088
# 1120
# 1152
# 1184
# 1216
# 1248
# 1280
# 1312
# 1344
# 1376
# 1408
# 1440
# 1472
# 1504
# 1536
# 1568
# 1600
# 1632
# 1664
# 1696
# 1728
# 1760
# 1792
# 1824
# 1856
# 1888
# 1920
# 1952
# 1984
# 2016
# 2048
# 2080
# 2112
# 2144
# 2176
# 2208
# 2240
# 2272
# 2304
# 2336
# 2368
# 2400
# 2432
# 2464
# 2496
# 2528
# 2560
# 2592
# 2624
# 2656
# 2688
# 2720
# 2752
# 2784
# 2816
# 2848
# 2880
# 2912
# 2944
# 2976
# 3008
# 3040
# 3072
# 3104
# 3136
# 3168
# 3200
# 3232
# 3264
# 3296
# 3328
# 3360
# 3392
# 3424
# 3456
# 3488
# 3520

# %%
# %%shell
# eval "$(conda shell.bash hook)"
# conda activate myenv
# pip install "numpy<2"
# Out:
# Collecting numpy<2
#   Downloading numpy-1.26.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Downloading numpy-1.26.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 112.3 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# Successfully installed numpy-1.26.4
